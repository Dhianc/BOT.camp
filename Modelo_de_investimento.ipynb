# %% [markdown]
# # Projeto 3 - Fazendo um modelo de investimento com Python - Factor Investing no Ibovespa.
#
# ## Desafio:
#
# * Construir um código que faça um backtesting dos últimos 6 anos, escolhendo as 10 melhores ações do índice ibovespa e utilizando como critério o fator momento 6 meses.
#
#
# ## Passo a passo da estratégia:
#
# **Passo 1** - Definir um universo investível.
#
# **Passo 2** - Escolher o fator que servirá como critério para criação dos rankings.
#
# **Passo 3** - Escolher o período de teste.
#
# **Passo 4** - Escolher o número de ações na carteira.
#
# **Passo 5** - Definir o período de balanceamento. De quanto em quanto tempo a carteira muda?
#
#
# ## Passo a passo do código:
#
# **Passo 1** - Ler a composição histórica do Ibovespa e os tickers que já passaram pelo índice.
#
# **Passo 2** - Puxar as cotações de todas as empresas que farão parte do backtest.
#
# **Passo 3** - Transformar o índice em data e ordenar a série de tempo.
#
# **Passo 4** - Calcular o retorno 6 meses e ajustar a tabela com o fator.
#
# **Passo 5** - Classificar e retirar empresas que não participaram do Ibovespa no período de tempo selecionado.
#
# **Passo 6** - Criar as carteiras de investimento em uma matriz de 0 ou 1.
#
# **Passo 7** - Calcular o retorno mensal das empresas no período de backtest.
#
# **Passo 8** - Cruzar a matriz de retorno mensal com a matriz das carteiras para chegar na rentabilidade do modelo.
#
# **Passo 9** - Puxar e calcular a rentabilidade do Ibovespa no período.
#
# **Passo 10** - Calcular e visualizar as rentabilidades do modelo contra o Ibovespa.

# %% [markdown]
# ## Estratégia:
#
# * 1 - Ibovespa
# * 2 - MTUM 6 meses
# * 3 - desde 2016
# * 4 - 10 ações
# * 5 - todo mês

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# ## Passo 1 - Ler a composição histórica do Ibovespa e os tickers que já passaram pelo índice

# %%
composicao_historica = pd.read_excel('composicao_ibov.xlsx')
lista_acoes = pd.read_excel('composicao_ibov.xlsx', sheet_name = 'lista_acoes')

lista_acoes
# Out:
#        tickers
# 0     ENEV3.SA
# 1     SOMA3.SA
# 2     ELET6.SA
# 3     BIDI4.SA
# 4     RAIZ4.SA
# ..         ...
# 102  VVAR11.SA
# 103   ABEV3.SA
# 104   BRPR3.SA
# 105   HYPE3.SA
# 106   LCAM3.SA
#
# [107 rows x 1 columns]

# %%
composicao_historica
# Out:
#    2015-12-31 2016-01-31 2016-02-29 2016-03-31 2016-04-30 2016-05-31  \
# 0       ABEV3      ABEV3      ITUB4      ITUB4      ITUB4      ITUB4
# 1       AMER3      BBAS3      ABEV3      BBDC4      BBDC4      ABEV3
# 2       AURE3      BBDC3      BBDC4      ABEV3      ABEV3      BBDC4
# 3       B3SA3      BBDC4      BRFS3      PETR4      PETR4      BRFS3
# 4       B3SA3      BBSE3      CIEL3      BRFS3      PETR3      PETR4
# ..        ...        ...        ...        ...        ...        ...
# 87        NaN        NaN        NaN        NaN        NaN        NaN
# 88        NaN        NaN        NaN        NaN        NaN        NaN
# 89        NaN        NaN        NaN        NaN        NaN        NaN
# 90        NaN        NaN        NaN        NaN        NaN        NaN
# 91        NaN        NaN        NaN        NaN        NaN        NaN
#
#    2016-06-30 2016-07-31 2016-08-31 2016-09-30  ... 2022-02-28 2022-03-31  \
# 0       ITUB4      ITUB4      ITUB4      ITUB4  ...      VALE3      VALE3
# 1       ABEV3      ABEV3      BBDC4      ABEV3  ...      PETR4      PETR4
# 2       BBDC4      BBDC4      ABEV3      BBDC4  ...      ITUB4      ITUB4
# 3       PETR4      PETR4      PETR4      PETR4  ...      PETR3      BBDC4
# 4       BRFS3      BRFS3      BRFS3      BRFS3  ...      BBDC4      B3SA3
# ..        ...        ...        ...        ...  ...        ...        ...
# 87        NaN        NaN        NaN        NaN  ...      EZTC3      JHSF3
# 88        NaN        NaN        NaN        NaN  ...      JHSF3      EZTC3
# 89        NaN        NaN        NaN        NaN  ...      CASH3      CASH3
# 90        NaN        NaN        NaN        NaN  ...      POSI3      POSI3
# 91        NaN        NaN        NaN        NaN  ...        NaN        NaN
#
#    2022-04-30 2022-05-31 2022-06-30 2022-07-31 2022-08-31 2022-09-30  \
# 0       VALE3      VALE3      VALE3      VALE3      VALE3      VALE3
# 1       PETR4      PETR4      PETR4      PETR4      PETR4      ITUB4
# 2       ITUB4      ITUB4      ITUB4      ITUB4      ITUB4      PETR4
# 3       BBDC4      BBDC4      BBDC4      PETR3      PETR3      BBDC4
# 4       PETR3      PETR3      PETR3      BBDC4      BBDC4      PETR3
# ..        ...        ...        ...        ...        ...        ...
# 87      JHSF3      GOLL4      GOLL4      GOLL4      GOLL4      CVCB3
# 88      EZTC3      JHSF3      EZTC3      CASH3      CASH3      GOLL4
# 89      CASH3      EZTC3      CASH3      POSI3      POSI3      ECOR3
# 90      POSI3      CASH3      POSI3        NaN        NaN      POSI3
# 91        NaN      POSI3        NaN        NaN        NaN      CASH3
#
#    2022-10-31 2022-11-30
# 0       VALE3      VALE3
# 1       PETR4      ITUB4
# 2       ITUB4      PETR4
# 3       BBDC4      BBDC4
# 4       PETR3      PETR3
# ..        ...        ...
# 87      CVCB3      EZTC3
# 88      ECOR3      ECOR3
# 89      GOLL4      CVCB3
# 90      POSI3      CASH3
# 91      CASH3      POSI3
#
# [92 rows x 84 columns]

# %% [markdown]
# ## Passo 2 - Puxar as cotações de todas as empresas que farão parte do backtest.

# %%
dados_cotacoes = (yf.download(lista_acoes['tickers'].to_list(), 
                             start = '2015-06-30', end = '2022-12-31')['Adj Close'])

dados_cotacoes
# Out:
# [*********************100%***********************]  107 of 107 completed
#
# 5 Failed downloads:
# - BIDI4.SA: No data found, symbol may be delisted
# - LCAM3.SA: No data found, symbol may be delisted
# - JPSA3.SA: No data found, symbol may be delisted
# - BIDI11.SA: No data found, symbol may be delisted
# - HGTX3.SA: No data found, symbol may be delisted
#              ABEV3.SA  ALPA4.SA   AMER3.SA   ARZZ3.SA  ASAI3.SA  AURE3.SA  \
# Date
# 2015-06-30  14.668835  5.577976  19.304613  19.890106       NaN       NaN
# 2015-07-01  14.776976  5.665766  18.623274  19.898390       NaN       NaN
# 2015-07-02  14.707462  5.631999  18.831461  20.088926       NaN       NaN
# 2015-07-03  14.792426  5.638752  18.594885  19.964668       NaN       NaN
# 2015-07-06  14.846499  5.604987  19.683134  19.964668       NaN       NaN
# ...               ...       ...        ...        ...       ...       ...
# 2017-02-27        NaN       NaN        NaN        NaN       NaN       NaN
# 2017-02-28        NaN       NaN        NaN        NaN       NaN       NaN
# 2017-04-21        NaN       NaN        NaN        NaN       NaN       NaN
# 2017-05-01        NaN       NaN        NaN        NaN       NaN       NaN
# 2022-03-01        NaN       NaN        NaN        NaN       NaN       NaN
#
#             AZUL4.SA  B3SA3.SA   BBAS3.SA  BBDC3.SA  ...   UGPA3.SA  USIM5.SA  \
# Date                                                 ...
# 2015-06-30       NaN  2.914593  16.064678  9.204793  ...  29.088474  3.501015
# 2015-07-01       NaN  2.894612  15.859571  9.145571  ...  28.809887  3.475523
# 2015-07-02       NaN  2.884623  15.813251  9.151251  ...  29.154812  3.492518
# 2015-07-03       NaN  2.857150  15.661073  9.177588  ...  28.951395  3.424537
# 2015-07-06       NaN  2.882125  15.780171  8.999829  ...  29.185766  3.552001
# ...              ...       ...        ...       ...  ...        ...       ...
# 2017-02-27       NaN       NaN        NaN       NaN  ...        NaN       NaN
# 2017-02-28       NaN       NaN        NaN       NaN  ...        NaN       NaN
# 2017-04-21       NaN       NaN        NaN       NaN  ...        NaN       NaN
# 2017-05-01       NaN       NaN        NaN       NaN  ...        NaN       NaN
# 2022-03-01       NaN       NaN        NaN       NaN  ...        NaN       NaN
#
#              VALE3.SA   VALE5.SA  VBBR3.SA  VIIA3.SA   VIVT3.SA  VVAR11.SA  \
# Date
# 2015-06-30  11.896466  14.912728       NaN  6.839885  21.685190  11.133475
# 2015-07-01  11.779388  14.759582       NaN  6.839885  21.480059  11.222941
# 2015-07-02  11.753369  14.797868       NaN  6.839885  22.007532  11.073833
# 2015-07-03  11.499699        NaN       NaN  7.655104  22.007532        NaN
# 2015-07-06  11.480186  14.328854       NaN  7.655104  21.984093  10.934664
# ...               ...        ...       ...       ...        ...        ...
# 2017-02-27        NaN        NaN       NaN       NaN        NaN  11.744440
# 2017-02-28        NaN        NaN       NaN       NaN        NaN  11.744440
# 2017-04-21        NaN        NaN       NaN       NaN        NaN  11.107453
# 2017-05-01        NaN        NaN       NaN       NaN        NaN  11.853922
# 2022-03-01        NaN        NaN       NaN       NaN        NaN        NaN
#
#             WEGE3.SA   YDUQ3.SA
# Date
# 2015-06-30  6.445274  13.737409
# 2015-07-01  6.604627  13.546081
# 2015-07-02  6.635140  13.622611
# 2015-07-03  6.723292  13.530774
# 2015-07-06  6.716511  13.431281
# ...              ...        ...
# 2017-02-27       NaN        NaN
# 2017-02-28       NaN        NaN
# 2017-04-21       NaN        NaN
# 2017-05-01       NaN        NaN
# 2022-03-01       NaN        NaN
#
# [1902 rows x 107 columns]

# %% [markdown]
# ## Passo 3 - Transformar o índice em data e ordenar a série de tempo.

# %%
dados_cotacoes.index = pd.to_datetime(dados_cotacoes.index)
dados_cotacoes = dados_cotacoes.sort_index()

dados_cotacoes
# Out:
#              ABEV3.SA   ALPA4.SA   AMER3.SA   ARZZ3.SA   ASAI3.SA  AURE3.SA  \
# Date
# 2015-06-30  14.668835   5.577976  19.304613  19.890106        NaN       NaN
# 2015-07-01  14.776976   5.665766  18.623274  19.898390        NaN       NaN
# 2015-07-02  14.707462   5.631999  18.831461  20.088926        NaN       NaN
# 2015-07-03  14.792426   5.638752  18.594885  19.964668        NaN       NaN
# 2015-07-06  14.846499   5.604987  19.683134  19.964668        NaN       NaN
# ...               ...        ...        ...        ...        ...       ...
# 2022-12-23  14.620000  14.800000   9.180000  80.849998  19.981815     15.05
# 2022-12-26  14.520000  14.680000   9.340000  78.559998  19.891987     14.78
# 2022-12-27  14.520000  14.450000   9.160000  76.570000  19.263187     14.72
# 2022-12-28  14.550000  15.120000   9.720000  78.680000  19.392941     14.79
# 2022-12-29  14.520000  15.080000   9.650000  78.250000  19.469999     14.73
#
#             AZUL4.SA   B3SA3.SA   BBAS3.SA   BBDC3.SA  ...   UGPA3.SA  \
# Date                                                   ...
# 2015-06-30       NaN   2.914593  16.064678   9.204793  ...  29.088474
# 2015-07-01       NaN   2.894612  15.859571   9.145571  ...  28.809887
# 2015-07-02       NaN   2.884623  15.813251   9.151251  ...  29.154812
# 2015-07-03       NaN   2.857150  15.661073   9.177588  ...  28.951395
# 2015-07-06       NaN   2.882125  15.780171   8.999829  ...  29.185766
# ...              ...        ...        ...        ...  ...        ...
# 2022-12-23     11.45  13.285341  35.279999  12.797478  ...  12.840000
# 2022-12-26     11.36  13.355002  35.230000  12.500532  ...  12.350000
# 2022-12-27     10.74  12.887279  34.060001  12.577163  ...  12.280000
# 2022-12-28     11.16  13.335098  34.669998  12.960320  ...  12.700000
# 2022-12-29     11.01  13.146019  34.730000  12.902847  ...  12.610000
#
#             USIM5.SA   VALE3.SA   VALE5.SA  VBBR3.SA  VIIA3.SA   VIVT3.SA  \
# Date
# 2015-06-30  3.501015  11.896466  14.912728       NaN  6.839885  21.685190
# 2015-07-01  3.475523  11.779388  14.759582       NaN  6.839885  21.480059
# 2015-07-02  3.492518  11.753369  14.797868       NaN  6.839885  22.007532
# 2015-07-03  3.424537  11.499699        NaN       NaN  7.655104  22.007532
# 2015-07-06  3.552001  11.480186  14.328854       NaN  7.655104  21.984093
# ...              ...        ...        ...       ...       ...        ...
# 2022-12-23  6.920000  86.320000        NaN     15.75  2.560000  37.426117
# 2022-12-26  6.960000  87.110001        NaN     15.24  2.550000  36.550312
# 2022-12-27  7.020000  89.190002        NaN     15.05  2.370000  36.404343
# 2022-12-28  7.160000  88.989998        NaN     15.52  2.450000  36.851978
# 2022-12-29  7.160000  88.879997        NaN     15.55  2.400000  37.319073
#
#             VVAR11.SA   WEGE3.SA   YDUQ3.SA
# Date
# 2015-06-30  11.133475   6.445274  13.737409
# 2015-07-01  11.222941   6.604627  13.546081
# 2015-07-02  11.073833   6.635140  13.622611
# 2015-07-03        NaN   6.723292  13.530774
# 2015-07-06  10.934664   6.716511  13.431281
# ...               ...        ...        ...
# 2022-12-23        NaN  38.500000  10.050000
# 2022-12-26        NaN  38.189999  10.190000
# 2022-12-27        NaN  38.009998   9.900000
# 2022-12-28        NaN  38.700001  10.430000
# 2022-12-29        NaN  38.509998  10.170000
#
# [1902 rows x 107 columns]

# %% [markdown]
# ## Passo 4 - Calcular o retorno 6 meses e ajustar a tabela com o fator.

# %%
r6 = dados_cotacoes.resample('M').last().pct_change(periods = 6).dropna(axis = 0, how = 'all').drop('2022-12-31')

r6
# Out:
#             ABEV3.SA  ALPA4.SA  AMER3.SA  ARZZ3.SA  ASAI3.SA  AURE3.SA  \
# Date
# 2015-12-31 -0.044826 -0.076286 -0.253431 -0.113005       NaN       NaN
# 2016-01-31 -0.026099  0.001545 -0.266998 -0.100444       NaN       NaN
# 2016-02-29 -0.054421  0.251857 -0.259615 -0.178820       NaN       NaN
# 2016-03-31 -0.016942  0.232223 -0.044415  0.183738       NaN       NaN
# 2016-04-30  0.031436  0.167526 -0.060357  0.164968       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-31 -0.002672 -0.243810 -0.547151 -0.018412  0.275232       NaN
# 2022-08-31  0.004605 -0.197824 -0.464262  0.153951  0.377360       NaN
# 2022-09-30  0.009091 -0.184120 -0.479939  0.106898  0.086093 -0.147533
# 2022-10-31  0.101928  0.120408 -0.352500  0.184724  0.297120  0.023815
# 2022-11-30  0.121917 -0.229885 -0.474627  0.127067  0.265783 -0.009312
#
#             AZUL4.SA  B3SA3.SA  BBAS3.SA  BBDC3.SA  ...  UGPA3.SA  USIM5.SA  \
# Date                                                ...
# 2015-12-31       NaN -0.019676 -0.362492 -0.235068  ... -0.076003 -0.623786
# 2016-01-31       NaN  0.030454 -0.340404 -0.260394  ... -0.150474 -0.783715
# 2016-02-29       NaN  0.116932 -0.208609 -0.034314  ... -0.003877 -0.697987
# 2016-03-31       NaN  0.435515  0.347494  0.330233  ...  0.052331 -0.459702
# 2016-04-30       NaN  0.561556  0.434324  0.376728  ...  0.087326 -0.100719
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-07-31 -0.598425 -0.223076  0.147972 -0.137303  ... -0.123544 -0.431752
# 2022-08-31 -0.347964 -0.167555  0.240283  0.040984  ... -0.046599 -0.425352
# 2022-09-30 -0.384615 -0.154352  0.136021  0.000961  ... -0.145272 -0.432637
# 2022-10-31 -0.265817  0.151202  0.140424  0.136441  ...  0.057887 -0.360743
# 2022-11-30 -0.389359  0.014829 -0.013285 -0.170037  ... -0.011830 -0.286496
#
#             VALE3.SA  VALE5.SA  VBBR3.SA  VIIA3.SA  VIVT3.SA  VVAR11.SA  \
# Date
# 2015-12-31 -0.273276 -0.325780       NaN -0.781977 -0.067328  -0.708036
# 2016-01-31 -0.445144 -0.493539       NaN -0.838961 -0.182059  -0.662428
# 2016-02-29 -0.327719 -0.380042       NaN -0.707792  0.000863  -0.364170
# 2016-03-31 -0.067891 -0.124446       NaN -0.110294  0.258974   0.406566
# 2016-04-30  0.154162  0.121882       NaN  0.024346  0.138833   0.442703
# ...              ...       ...       ...       ...       ...        ...
# 2022-07-31 -0.104346  0.000000 -0.268993 -0.491525 -0.069730   0.000000
# 2022-08-31 -0.236548  0.000000 -0.217495 -0.150396 -0.150280   0.000000
# 2022-09-30 -0.207386  0.000000 -0.244360 -0.235012 -0.216785   0.000000
# 2022-10-31 -0.152247  0.000000 -0.119768  0.053872 -0.213826   0.000000
# 2022-11-30  0.045730  0.000000 -0.133827 -0.305732 -0.246783   0.000000
#
#             WEGE3.SA  YDUQ3.SA
# Date
# 2015-12-31 -0.204485 -0.222841
# 2016-01-31 -0.167807 -0.177091
# 2016-02-29 -0.202454  0.023256
# 2016-03-31 -0.078546 -0.159574
# 2016-04-30  0.068156 -0.207022
# ...              ...       ...
# 2022-07-31 -0.115124 -0.396184
# 2022-08-31 -0.030147 -0.416317
# 2022-09-30 -0.070701 -0.304705
# 2022-10-31  0.349226  0.000620
# 2022-11-30  0.549908 -0.289246
#
# [84 rows x 107 columns]

# %% [markdown]
# ## Passo 5 - Classificar e retirar empresas que não participaram do Ibovespa no período de tempo selecionado.

# %%
for data in r6.index:
    for empresa in r6.columns:
        if empresa.replace('.SA', '') not in composicao_historica.loc[:, data].to_list():
            r6.loc[data, empresa] = pd.NA
            
r6
# Out:
#             ABEV3.SA  ALPA4.SA  AMER3.SA  ARZZ3.SA  ASAI3.SA  AURE3.SA  \
# Date
# 2015-12-31 -0.044826       NaN -0.253431       NaN       NaN       NaN
# 2016-01-31 -0.026099       NaN -0.266998       NaN       NaN       NaN
# 2016-02-29 -0.054421       NaN -0.259615       NaN       NaN       NaN
# 2016-03-31 -0.016942       NaN -0.044415       NaN       NaN       NaN
# 2016-04-30  0.031436       NaN -0.060357       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-31 -0.002672 -0.243810 -0.547151       NaN  0.275232       NaN
# 2022-08-31  0.004605 -0.197824 -0.464262       NaN  0.377360       NaN
# 2022-09-30  0.009091 -0.184120 -0.479939  0.106898  0.086093       NaN
# 2022-10-31  0.101928  0.120408 -0.352500  0.184724  0.297120       NaN
# 2022-11-30  0.121917 -0.229885 -0.474627  0.127067  0.265783       NaN
#
#             AZUL4.SA  B3SA3.SA  BBAS3.SA  BBDC3.SA  ...  UGPA3.SA  USIM5.SA  \
# Date                                                ...
# 2015-12-31       NaN -0.019676 -0.362492 -0.235068  ... -0.076003 -0.623786
# 2016-01-31       NaN  0.030454 -0.340404 -0.260394  ... -0.150474 -0.783715
# 2016-02-29       NaN  0.116932 -0.208609 -0.034314  ... -0.003877 -0.697987
# 2016-03-31       NaN  0.435515  0.347494  0.330233  ...  0.052331 -0.459702
# 2016-04-30       NaN  0.561556  0.434324  0.376728  ...  0.087326 -0.100719
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-07-31 -0.598425 -0.223076  0.147972 -0.137303  ... -0.123544 -0.431752
# 2022-08-31 -0.347964 -0.167555  0.240283  0.040984  ... -0.046599 -0.425352
# 2022-09-30 -0.384615 -0.154352  0.136021  0.000961  ... -0.145272 -0.432637
# 2022-10-31 -0.265817  0.151202  0.140424  0.136441  ...  0.057887 -0.360743
# 2022-11-30 -0.389359  0.014829 -0.013285 -0.170037  ... -0.011830 -0.286496
#
#             VALE3.SA  VALE5.SA  VBBR3.SA  VIIA3.SA  VIVT3.SA  VVAR11.SA  \
# Date
# 2015-12-31 -0.273276 -0.325780       NaN       NaN -0.067328        NaN
# 2016-01-31 -0.445144 -0.493539       NaN       NaN -0.182059        NaN
# 2016-02-29 -0.327719 -0.380042       NaN       NaN  0.000863        NaN
# 2016-03-31 -0.067891 -0.124446       NaN       NaN  0.258974        NaN
# 2016-04-30  0.154162  0.121882       NaN       NaN  0.138833        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2022-07-31 -0.104346       NaN -0.268993 -0.491525 -0.069730        NaN
# 2022-08-31 -0.236548       NaN -0.217495 -0.150396 -0.150280        NaN
# 2022-09-30 -0.207386       NaN -0.244360 -0.235012 -0.216785        NaN
# 2022-10-31 -0.152247       NaN -0.119768  0.053872 -0.213826        NaN
# 2022-11-30  0.045730       NaN -0.133827 -0.305732 -0.246783        NaN
#
#             WEGE3.SA  YDUQ3.SA
# Date
# 2015-12-31       NaN -0.222841
# 2016-01-31 -0.167807 -0.177091
# 2016-02-29 -0.202454  0.023256
# 2016-03-31 -0.078546 -0.159574
# 2016-04-30  0.068156 -0.207022
# ...              ...       ...
# 2022-07-31 -0.115124 -0.396184
# 2022-08-31 -0.030147 -0.416317
# 2022-09-30 -0.070701 -0.304705
# 2022-10-31  0.349226  0.000620
# 2022-11-30  0.549908 -0.289246
#
# [84 rows x 107 columns]

# %% [markdown]
# ## Passo 6 - Criar as carteiras de investimento em uma matriz de 0 ou 1.

# %%
carteiras = r6.rank(axis = 1, ascending = False).applymap(lambda x: 1 if x < 11 else 0)
carteiras
# Out:
#             ABEV3.SA  ALPA4.SA  AMER3.SA  ARZZ3.SA  ASAI3.SA  AURE3.SA  \
# Date
# 2015-12-31         0         0         0         0         0         0
# 2016-01-31         0         0         0         0         0         0
# 2016-02-29         0         0         0         0         0         0
# 2016-03-31         0         0         0         0         0         0
# 2016-04-30         0         0         0         0         0         0
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-31         0         0         0         0         1         0
# 2022-08-31         0         0         0         0         1         0
# 2022-09-30         0         0         0         0         0         0
# 2022-10-31         0         0         0         0         0         0
# 2022-11-30         0         0         0         0         1         0
#
#             AZUL4.SA  B3SA3.SA  BBAS3.SA  BBDC3.SA  ...  UGPA3.SA  USIM5.SA  \
# Date                                                ...
# 2015-12-31         0         0         0         0  ...         0         0
# 2016-01-31         0         1         0         0  ...         0         0
# 2016-02-29         0         0         0         0  ...         0         0
# 2016-03-31         0         1         0         0  ...         0         0
# 2016-04-30         0         1         1         0  ...         0         0
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-07-31         0         0         0         0  ...         0         0
# 2022-08-31         0         0         0         0  ...         0         0
# 2022-09-30         0         0         0         0  ...         0         0
# 2022-10-31         0         0         0         0  ...         0         0
# 2022-11-30         0         0         0         0  ...         0         0
#
#             VALE3.SA  VALE5.SA  VBBR3.SA  VIIA3.SA  VIVT3.SA  VVAR11.SA  \
# Date
# 2015-12-31         0         0         0         0         0          0
# 2016-01-31         0         0         0         0         0          0
# 2016-02-29         0         0         0         0         0          0
# 2016-03-31         0         0         0         0         0          0
# 2016-04-30         0         0         0         0         0          0
# ...              ...       ...       ...       ...       ...        ...
# 2022-07-31         0         0         0         0         0          0
# 2022-08-31         0         0         0         0         0          0
# 2022-09-30         0         0         0         0         0          0
# 2022-10-31         0         0         0         0         0          0
# 2022-11-30         0         0         0         0         0          0
#
#             WEGE3.SA  YDUQ3.SA
# Date
# 2015-12-31         0         0
# 2016-01-31         0         0
# 2016-02-29         0         0
# 2016-03-31         0         0
# 2016-04-30         0         0
# ...              ...       ...
# 2022-07-31         0         0
# 2022-08-31         0         0
# 2022-09-30         0         0
# 2022-10-31         1         0
# 2022-11-30         1         0
#
# [84 rows x 107 columns]

# %% [markdown]
# ## Passo 7 - Calcular o retorno mensal das empresas no período de backtest.

# %%
retorno_mensal = dados_cotacoes.resample('M').last().pct_change(periods = 1)

retorno_mensal = retorno_mensal.drop(retorno_mensal.index[:7], axis = 0)

retorno_mensal.index = carteiras.index

retorno_mensal
# Out:
#             ABEV3.SA  ALPA4.SA  AMER3.SA  ARZZ3.SA  ASAI3.SA  AURE3.SA  \
# Date
# 2015-12-31  0.045378  0.023876 -0.129350 -0.095238       NaN       NaN
# 2016-01-31 -0.048030  0.219479 -0.128959 -0.062632       NaN       NaN
# 2016-02-29  0.065760 -0.123003  0.229437  0.311061       NaN       NaN
# 2016-03-31  0.031383  0.193548 -0.035211  0.038544       NaN       NaN
# 2016-04-30 -0.014441  0.084495 -0.277372  0.026240       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-31  0.022773 -0.061392  0.167143  0.167404  0.160252  0.083157
# 2022-08-31  0.017682  0.030523  0.039168  0.065043 -0.045677 -0.118412
# 2022-09-30  0.029601  0.032440 -0.084806  0.061884  0.129345  0.101107
# 2022-10-31 -0.005000 -0.237250 -0.320463 -0.142871  0.011604 -0.073056
# 2022-11-30 -0.039883 -0.099701 -0.086174 -0.117489 -0.027072  0.065076
#
#             AZUL4.SA  B3SA3.SA  BBAS3.SA  BBDC3.SA  ...  UGPA3.SA  USIM5.SA  \
# Date                                                ...
# 2015-12-31       NaN -0.057851 -0.060380 -0.043574  ... -0.017701 -0.451613
# 2016-01-31       NaN  0.132554 -0.022383  0.188886  ...  0.064734  0.058823
# 2016-02-29       NaN  0.320998  0.475473  0.293587  ...  0.111854  1.011111
# 2016-03-31       NaN  0.119218  0.118361  0.027804  ...  0.036348  0.381215
# 2016-04-30       NaN -0.067894 -0.249184 -0.126903  ... -0.057581 -0.332000
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-07-31  0.405797  0.068530  0.164769  0.095988  ...  0.066194 -0.068525
# 2022-08-31 -0.107338  0.108099 -0.069854  0.030794  ... -0.133038 -0.062344
# 2022-09-30  0.095788  0.152490 -0.038941  0.021246  ...  0.143223 -0.038564
# 2022-10-31 -0.238686 -0.153591 -0.042371 -0.172222  ...  0.058911  0.081604
# 2022-11-30 -0.103420  0.039749 -0.005419 -0.019816  ... -0.111972 -0.084399
#
#             VALE3.SA  VALE5.SA  VBBR3.SA  VIIA3.SA  VIVT3.SA  VVAR11.SA  \
# Date
# 2015-12-31 -0.254029 -0.293659       NaN -0.173333 -0.083430  -0.107034
# 2016-01-31  0.215020  0.182321       NaN  0.814516  0.095161   0.482876
# 2016-02-29  0.282811  0.329439       NaN  0.075556  0.130946   0.286374
# 2016-03-31  0.299670  0.383128       NaN  0.227522 -0.009379   0.100806
# 2016-04-30 -0.277806 -0.285896       NaN -0.124579 -0.030320   0.016313
# ...              ...       ...       ...       ...       ...        ...
# 2022-07-31 -0.027340  0.000000  0.102703  0.341667 -0.077578   0.000000
# 2022-08-31  0.116899  0.000000 -0.042928 -0.009317 -0.011481   0.000000
# 2022-09-30 -0.068157  0.000000  0.057971 -0.018809  0.020252   0.000000
# 2022-10-31  0.276776  0.000000 -0.094247 -0.303514 -0.078916   0.000000
# 2022-11-30  0.040514  0.000000 -0.034995  0.100917  0.007884   0.000000
#
#             WEGE3.SA  YDUQ3.SA
# Date
# 2015-12-31  0.034113 -0.160573
# 2016-01-31 -0.142028  0.089667
# 2016-02-29  0.069196 -0.071317
# 2016-03-31  0.080427  0.034552
# 2016-04-30 -0.052042 -0.085088
# ...              ...       ...
# 2022-07-31  0.008916 -0.070943
# 2022-08-31  0.137732  0.173842
# 2022-09-30  0.253267  0.116263
# 2022-10-31 -0.031778 -0.287043
# 2022-11-30 -0.011129 -0.115652
#
# [84 rows x 107 columns]

# %% [markdown]
# ## Passo 8 - Cruzar a matriz de retorno mensal com a matriz das carteiras para chegar na rentabilidade do modelo.

# %%
retorno_modelo = (retorno_mensal * carteiras).sum(axis = 1) / 10

retorno_modelo
# Out:
# Date
# 2015-12-31   -0.043231
# 2016-01-31    0.076903
# 2016-02-29    0.091320
# 2016-03-31    0.165053
# 2016-04-30   -0.164843
#                 ...
# 2022-07-31    0.114667
# 2022-08-31   -0.060277
# 2022-09-30    0.089395
# 2022-10-31   -0.138985
# 2022-11-30   -0.024385
# Freq: M, Length: 84, dtype: float64

# %% [markdown]
# ## Passo 8.2 - Visualizar a rentabilidade do modelo com o quantstats

# %%
# !pip install QuantStats
import quantstats as qs
# Out:
# Collecting QuantStats
#   Downloading QuantStats-0.0.59-py2.py3-none-any.whl (41 kB)
#      ---------------------------------------- 41.3/41.3 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24.0 in c:\users\user\anaconda3\lib\site-packages (from QuantStats) (1.5.2)
# Requirement already satisfied: yfinance>=0.1.70 in c:\users\user\anaconda3\lib\site-packages (from QuantStats) (0.1.74)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from QuantStats) (3.6.2)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from QuantStats) (0.12.2)
# Requirement already satisfied: python-dateutil>=2.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from QuantStats) (2.8.2)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from QuantStats) (1.9.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\user\anaconda3\lib\site-packages (from QuantStats) (1.23.5)
# Requirement already satisfied: tabulate>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from QuantStats) (0.8.10)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->QuantStats) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.0.0->QuantStats) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.0.0->QuantStats) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.0.0->QuantStats) (1.0.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.0.0->QuantStats) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->QuantStats) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.0.0->QuantStats) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.24.0->QuantStats) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.0->QuantStats) (1.16.0)
# Requirement already satisfied: requests>=2.26 in c:\users\user\anaconda3\lib\site-packages (from yfinance>=0.1.70->QuantStats) (2.28.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\user\anaconda3\lib\site-packages (from yfinance>=0.1.70->QuantStats) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\user\anaconda3\lib\site-packages (from yfinance>=0.1.70->QuantStats) (4.9.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->QuantStats) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->QuantStats) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->QuantStats) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->QuantStats) (1.26.14)
# Installing collected packages: QuantStats
# Successfully installed QuantStats-0.0.59

# %%
qs.extend_pandas()

retorno_modelo.plot_monthly_heatmap()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\quantstats\stats.py:968: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   returns = returns.pivot('Year', 'Month', 'Returns').fillna(0)

# %% [markdown]
# ## Passo 9 - Puxar e calcular a rentabilidade do Ibovespa no período.

# %%
ibovespa = yf.download('^BVSP', start = '2015-12-30', end = '2022-12-31')['Adj Close']

ibovespa = ibovespa.resample('M').last().pct_change().dropna()

ibovespa
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2016-01-31   -0.067912
# 2016-02-29    0.059100
# 2016-03-31    0.169673
# 2016-04-30    0.077035
# 2016-05-31   -0.100889
#                 ...
# 2022-08-31    0.061629
# 2022-09-30    0.004693
# 2022-10-31    0.054527
# 2022-11-30   -0.030602
# 2022-12-31   -0.021825
# Freq: M, Name: Adj Close, Length: 84, dtype: float64

# %% [markdown]
# ## Passo 10 - Calcular e visualizar as rentabilidades do modelo contra o Ibovespa.

# %%
retorno_acum_modelo = (1 + retorno_modelo).cumprod() - 1
retorno_acum_ibov = (1 + ibovespa).cumprod() - 1

retorno_acum_modelo.plot_monthly_heatmap()
retorno_acum_ibov.plot_monthly_heatmap()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\quantstats\stats.py:968: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   returns = returns.pivot('Year', 'Month', 'Returns').fillna(0)
# C:\Users\User\anaconda3\lib\site-packages\quantstats\stats.py:968: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   returns = returns.pivot('Year', 'Month', 'Returns').fillna(0)
