# %% [markdown]
# # Projeto 2 - Como pegar dados de um site com Python? - Pegando dados de ETFs do mundo inteiro.
#
#
# # Desafio:
#
# * Construir um código que vá no site etf.com e busque dados de todos os etfs do mercado americano e, consequentemente, do mundo. Rentabilidade, patrimônio, gestora, taxa...
#
#
# # Passo a passo:
#
# **Passo 1** - Definir um navegador que você irá utilizar para navegar com o Python.
#
# **Passo 2** - Importar os módulos e bibliotecas.
#
# **Passo 3** - Entender como funcionam requisições na internet.
#
# **Passo 4** - Conhecer e mapear o processo de coleta de dados no site ETF.com.
#
# **Passo 5** - Achar todos os elementos necessários dentro do HTML do site.
#
# **Passo 6** - Ler a tabela de dados.
#
# **Passo 7** - Construir a tabela final.

# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.8.5-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python39\site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from webdriver-manager) (2.28.1)
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\appdata\roaming\python\python39\site-packages (from packaging->webdriver-manager) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver-manager) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python39\site-packages (from tqdm->webdriver-manager) (0.4.5)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-0.21.1 webdriver-manager-3.8.5

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.8.0-py3-none-any.whl (6.3 MB)
#      ---------------------------------------- 6.3/6.3 MB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\user\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Collecting trio~=0.17
#   Using cached trio-0.22.0-py3-none-any.whl (384 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\user\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Collecting trio-websocket~=0.9
#   Using cached trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Collecting async-generator>=1.9
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting outcome
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: sortedcontainers in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting wsproto>=0.14
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 exceptiongroup-1.1.0 h11-0.14.0 outcome-1.2.0 selenium-4.8.0 trio-0.22.0 trio-websocket-0.9.2 wsproto-1.2.0

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\user\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\user\appdata\roaming\python\python39\site-packages (from html5lib) (1.16.0)

# %% [markdown]
# ## Passo 1: Escolher o navegador
#
# Será usado o Google Chrome.

# %% [markdown]
# ## Passo 2: Importar bibliotecas

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# %% [markdown]
# ## Passo3: Entender como funcionam requisições na internet

# %%
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))

url = "https://www.etf.com/etfanalytics/etf-finder"

driver.get(url)

# %% [markdown]
# ## Passo 4: Conhecer e mapear o procesos de coleta de dados no site ETF.com

# %% [markdown]
# ### Processo de dados
#
# * Abrir o site
# * Mudar a visualização pra 100
# * Ler a tabela
# * Avançar todas as páginas
# * Trocar pra outra categoria
# * Ler todas as tabelas dessa outra categoria

# %% [markdown]
# ## Passo 5.1: Achar todos os elementos necessários dentro do HTML do site - Expandindo a tabela para 100 itens

# %%
time.sleep(5)

botao_100 = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]
                                /section[2]/div[2]/section[2]/div[1]/div/div[4]/button/label/span''')

driver.execute_script('arguments[0].click()', botao_100)

# %% [markdown]
# ## Passo 5.2: Achar todos os elementos necessários dentro do HTML do site - Pegando o número de páginas da tabela

# %%
numero_paginas = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]
                                    /section[2]/div[2]/section[2]/div[2]/div/label[2]''')

numero_paginas = numero_paginas.text.replace('of ', '')
numero_paginas = int(numero_paginas)

print(numero_paginas)
# Out:
# 31

# %% [markdown]
# ## Passo 6.1: Ler a tabela de dados - Lendo a tabela de dados básicos

# %%
lista_de_tabela_por_pagina = []

for pagina in range(0, numero_paginas):
    tabela = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div/div
                                        /div/div[2]/section[2]/div[2]/div/table''')

    html_tabela = tabela.get_attribute('outerHTML')

    tabela_final = pd.read_html(html_tabela)[0]
     
    lista_de_tabela_por_pagina.append(tabela_final)
    
    botao_avancar_pagina = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div/
                                                div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]''')
    
    driver.execute_script('arguments[0].click()', botao_avancar_pagina)
    
base_de_dados_basic = pd.concat(lista_de_tabela_por_pagina)
base_de_dados_basic = base_de_dados_basic.set_index('Ticker')
base_de_dados_basic
# Out:
#                                               Name  \
# Ticker
# SPY                         SPDR S&P 500 ETF Trust
# IVV                       iShares Core S&P 500 ETF
# VTI                Vanguard Total Stock Market ETF
# VOO                           Vanguard S&P 500 ETF
# QQQ                              Invesco QQQ Trust
# ...                                            ...
# AWYX                ETFMG 2x Daily Travel Tech ETF
# TADS                 The Active Dividend Stock ETF
# CRYP    AdvisorShares Managed Bitcoin Strategy ETF
# FLRU                      Franklin FTSE Russia ETF
# NBCM       Neuberger Berman Commodity Strategy ETF
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# VOO                              Equity: U.S. - Large Cap
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# AWYX    Leveraged Equity: Global Internet & Direct Mar...
# TADS                          Equity: U.S. - Total Market
# CRYP              Asset Allocation: Global Target Outcome
# FLRU                        Equity: Russia - Total Market
# NBCM                            Commodities: Broad Market
#
#                                  Issuer Expense Ratio       AUM
# Ticker
# SPY        State Street Global Advisors         0.09%  $383.85B
# IVV                           Blackrock         0.03%  $312.01B
# VTI                            Vanguard         0.03%  $285.80B
# VOO                            Vanguard         0.03%  $283.28B
# QQQ                             Invesco         0.20%  $161.67B
# ...                                 ...           ...       ...
# AWYX                              ETFMG         0.95%  $345.20K
# TADS    Tuttle Tactical Management, LLC         1.68%  $294.89K
# CRYP                      AdvisorShares         1.59%  $218.67K
# FLRU                 Franklin Templeton         0.19%    $8.00K
# NBCM                   Neuberger Berman         0.65%        --
#
# [3090 rows x 5 columns]

# %% [markdown]
# ## Passo 6.2: Ler a tabela de dados - Lendo a tabela de dados de rentabilidade

# %%
# Mudar a aba
botao_aba = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div
                                                /div/div/div[2]/section[2]/div[2]/ul/li[2]/span''')
driver.execute_script('arguments[0].click()', botao_aba)

# Voltar para página 1
caixa_de_texto = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div/div
                                                /div/div[2]/section[2]/div[2]/section[2]/div[2]/div/input''')

for pagina in range(0, numero_paginas):
    botao_voltar_pagina = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div/
                                                        div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[1]''')
    
    driver.execute_script('arguments[0].click()', botao_voltar_pagina)

# %%
lista_de_tabela_por_pagina = []

for pagina in range(0, numero_paginas):
    tabela = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div/div
                                        /div/div[2]/section[2]/div[2]/div/table''')

    html_tabela = tabela.get_attribute('outerHTML')

    tabela_final = pd.read_html(html_tabela)[0]
     
    lista_de_tabela_por_pagina.append(tabela_final)
    
    botao_avancar_pagina = driver.find_element('xpath', '''/html/body/div[5]/section/div/div[3]/section/div/div/
                                                div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]''')
    
    driver.execute_script('arguments[0].click()', botao_avancar_pagina)
    
base_de_dados_performance = pd.concat(lista_de_tabela_por_pagina)
base_de_dados_performance = base_de_dados_performance.set_index('Ticker')

base_de_dados_performance
# Out:
#                                               Name 1 Month 3 Month     YTD  \
# Ticker
# SPY                         SPDR S&P 500 ETF Trust   4.03%   8.84%   3.52%
# IVV                       iShares Core S&P 500 ETF   4.06%   8.84%   3.51%
# VTI                Vanguard Total Stock Market ETF   4.49%   8.98%   3.96%
# VOO                           Vanguard S&P 500 ETF   4.02%   8.82%   3.52%
# QQQ                              Invesco QQQ Trust   4.88%   5.30%   6.16%
# ...                                            ...     ...     ...     ...
# AWYX                ETFMG 2x Daily Travel Tech ETF  36.11%  38.66%  31.27%
# TADS                 The Active Dividend Stock ETF      0%      0%      0%
# CRYP    AdvisorShares Managed Bitcoin Strategy ETF      --      --      --
# FLRU                      Franklin FTSE Russia ETF      0%      0%      0%
# NBCM       Neuberger Berman Commodity Strategy ETF   4.82%      --   1.82%
#
#          1 Year  3 Years 5 Years 10 Years As Of Date
# Ticker
# SPY      -9.95%    7.75%   8.99%   12.39%   01/20/23
# IVV      -9.95%    7.75%   9.03%   12.44%   01/20/23
# VTI     -10.36%    7.24%   8.49%   12.02%   01/20/23
# VOO      -9.98%    7.73%   9.02%   12.44%   01/20/23
# QQQ     -21.28%    8.84%  11.98%   16.55%   01/20/23
# ...         ...      ...     ...      ...        ...
# AWYX    -48.46%       --      --       --   01/20/23
# TADS         0%       --      --       --   01/20/23
# CRYP         --       --      --       --   01/20/23
# FLRU    -66.37%  -31.18%      --       --   01/20/23
# NBCM         --       --      --       --   01/20/23
#
# [3090 rows x 9 columns]

# %%
driver.quit()

# %% [markdown]
# ## Passo 7: Construir a tabela final

# %%
base_de_dados_performance = base_de_dados_performance[['1 Year', '5 Years', '10 Years']]
base_de_dados_performance
# Out:
#          1 Year 5 Years 10 Years
# Ticker
# SPY      -9.95%   8.99%   12.39%
# IVV      -9.95%   9.03%   12.44%
# VTI     -10.36%   8.49%   12.02%
# VOO      -9.98%   9.02%   12.44%
# QQQ     -21.28%  11.98%   16.55%
# ...         ...     ...      ...
# AWYX    -48.46%      --       --
# TADS         0%      --       --
# CRYP         --      --       --
# FLRU    -66.37%      --       --
# NBCM         --      --       --
#
# [3090 rows x 3 columns]

# %%
base_de_dados_final = base_de_dados_basic.join(base_de_dados_performance)
base_de_dados_final
# Out:
#                                               Name  \
# Ticker
# SPY                         SPDR S&P 500 ETF Trust
# IVV                       iShares Core S&P 500 ETF
# VTI                Vanguard Total Stock Market ETF
# VOO                           Vanguard S&P 500 ETF
# QQQ                              Invesco QQQ Trust
# ...                                            ...
# AWYX                ETFMG 2x Daily Travel Tech ETF
# TADS                 The Active Dividend Stock ETF
# CRYP    AdvisorShares Managed Bitcoin Strategy ETF
# FLRU                      Franklin FTSE Russia ETF
# NBCM       Neuberger Berman Commodity Strategy ETF
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# VOO                              Equity: U.S. - Large Cap
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# AWYX    Leveraged Equity: Global Internet & Direct Mar...
# TADS                          Equity: U.S. - Total Market
# CRYP              Asset Allocation: Global Target Outcome
# FLRU                        Equity: Russia - Total Market
# NBCM                            Commodities: Broad Market
#
#                                  Issuer Expense Ratio       AUM   1 Year  \
# Ticker
# SPY        State Street Global Advisors         0.09%  $383.85B   -9.95%
# IVV                           Blackrock         0.03%  $312.01B   -9.95%
# VTI                            Vanguard         0.03%  $285.80B  -10.36%
# VOO                            Vanguard         0.03%  $283.28B   -9.98%
# QQQ                             Invesco         0.20%  $161.67B  -21.28%
# ...                                 ...           ...       ...      ...
# AWYX                              ETFMG         0.95%  $345.20K  -48.46%
# TADS    Tuttle Tactical Management, LLC         1.68%  $294.89K       0%
# CRYP                      AdvisorShares         1.59%  $218.67K       --
# FLRU                 Franklin Templeton         0.19%    $8.00K  -66.37%
# NBCM                   Neuberger Berman         0.65%        --       --
#
#        5 Years 10 Years
# Ticker
# SPY      8.99%   12.39%
# IVV      9.03%   12.44%
# VTI      8.49%   12.02%
# VOO      9.02%   12.44%
# QQQ     11.98%   16.55%
# ...        ...      ...
# AWYX        --       --
# TADS        --       --
# CRYP        --       --
# FLRU        --       --
# NBCM        --       --
#
# [3090 rows x 8 columns]
